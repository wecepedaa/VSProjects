# %%
import math
import collections

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp
# %matplotlib inline

lengths = [293, 922, 1728, 4148, 10380, 28835, 43190]
Totals = [9, 12, 72, 614, 1208, 3183, 6019]

pp.plot( lengths, Totals)

# %%
import random

def GenRandList(start, end, num):
    res = []
    for j in range(num):
        res.append(random.randint(start,end))
    res.sort(reverse=False)
    return res


l1 = GenRandList(100,2000,128)
l2 = GenRandList(10,1000,128)


pp.plot( l1, l2)
pp.scatter( l2, l1)

# %%
def n_arguments(*args):
    print(args)

n_arguments(1,2,3,4,5)
# Out:
# (1, 2, 3, 4, 5)
